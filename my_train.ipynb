# %%
import torch
import os
import yaml

# %%
cur_dir=os.curdir

# %%
data={"path":"../datsets/infrared",
      "train":"images/train",
      "val":"images/val",
      "test":"images/val",
      "nc":3,
      "names":["person","bicycle","car"]}

with open(os.path.join(cur_dir,"yolov5","data.yaml"),"w") as fin:
      
      yaml.dump(data,fin)

# %%
#img_size------> [336,256]
#batch---------> 32
#epochs---------> 1
#data ./DataFile/data.yaml
#cfg ./DataFile/customYOLOv5x.yaml
#weights--------> yolov5x.pt  
#name---------> Result 
#cache

# %%
# !cd yolov5

# %%
# %%time
# !python yolov5/train.py --img 336 --rect  --batch 16 --epochs 1 --data yolov5/data.yaml --weights yolov5s.pt  --name Result --cache --device 0 --nw 1
# Out:
# CPU times: total: 0 ns
# Wall time: 498 ms
# Traceback (most recent call last):
#   File "yolov5/train.py", line 26, in <module>
#     import torch
#   File "C:\Users\bgnva\anaconda3\lib\site-packages\torch\__init__.py", line 126, in <module>
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "C:\Users\bgnva\anaconda3\lib\site-packages\torch\lib\cufft64_10.dll" or one of its dependencies.

# %%
# !python yolov5/detect.py --weights yolov5/runs/train/Result3/weights/best.pt --source test.mp4
# Out:
# detect: weights=['yolov5/runs/train/Result3/weights/best.pt'], source=test.mp4, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# fatal: cannot change to 'C:\Users\bgnva\Desktop\Projects\Infrared': No such file or directory
# YOLOv5  2022-4-12 torch 1.11.0+cu113 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients
# WARNING: NMS time limit 0.130s exceeded
# video 1/1 (1/183) C:\Users\bgnva\Desktop\Projects\Infrared image detection\test.mp4: 384x640 1 person, Done. (0.073s)
# ...
